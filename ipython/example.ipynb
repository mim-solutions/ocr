# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /home/mbrzozowski/projects/media_monitoring/ocr

# %%
from PIL import Image

from lib.parse_png import parse_png

# %%
img = Image.open('test/sample_data/example.png')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=596x1208 at 0x7F2CFE02DB20>

# %%
result = parse_png(img)
# Out:
# Running Cloud Vision OCR on 7 images

# %%
print(result)
# Out:
# 14 kwietnia 2021 r. sopocki
# Certo Broker nabył 100% udziałów
# w łódzkiej spółce Mount Broker.
# Transakcji towarzyszą zmiany
# we władzach przejętego podmiotu,
# który docelowo będzie działać pod
# nazwą przejmującego go brokera.
#
# Mount Broker
# przejęty przez
# Certo Broker
#
# rzejmująca fir-
# ma jest broke-
# rem ubezpie-
#
# czeniowym specjali-
# zującym się w ubez-
# pieczeniach na życie
# i zdrowotnych. Preze-
# sem Certo Broker
# jest Daniel Zdziński,
# który często gości
# na łamach „Gazety
# Ubezpieczeniowej".
#
# To ważny krok
# w rozwoju spółki. Ten
# zakup pozwoli na dal-
# Daniel Zdziński
# szą rozbudowę nasze-
# go portfela i umocni markę Certo Broker na rynku.
# Cieszę się, że Tomasz Góra - dotychczasowy właściciel
# Mount Broker - zaufał nam, powierzając spółkę
# ,
# i klientów, z którymi współpracował od kilku lat - sko-
# -
